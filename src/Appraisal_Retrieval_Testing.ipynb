# %%
import requests
import pandas as pd
import time

# %%
appraisal_links = [
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=1081&LayerID=26490&PageTypeID=4&PageID=10770&Q=320373606&KeyValue=10617-016-000",
    "https://bakerpa.com/propertydetails.php?parcel=362S21005100330040",
    "https://qpublic.schneidercorp.com/application.aspx?AppID=834&LayerID=15170&PageTypeID=4&PageID=6825&Q=192963963&KeyValue=01755-000-000",
    "https://paopropertysearch.coj.net/Basic/Detail.aspx?RE=1677581005",
    "https://www.escpa.org/cama/Detail_a.aspx?s=191S311103006001",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=598&LayerID=9801&PageTypeID=4&PageID=4330&Q=1542956115&KeyValue=13-12-28-1800-01500-0310",
    "https://beacon.schneidercorp.com/Application.aspx?AppID=819&LayerID=15077&PageTypeID=4&PageID=6971&KeyValue=05004-050R",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=820&LayerID=15174&PageTypeID=4&PageID=6883&Q=1071567062&KeyValue=17-09-16-0522-0000-0560",
    "https://beacon.schneidercorp.com/Application.aspx?AppID=1105&LayerID=27399&PageTypeID=4&PageID=11143&Q=1216707878&KeyValue=1+34+43+21+010+000Q-015.0",
    "https://gis.hcpafl.org/propertysearch/#/parcel/basic/1930251RO000003000220U",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=1109&LayerID=27655&PageTypeID=4&PageID=11279&Q=1438314085&KeyValue=31392900000500000018.0",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=851&LayerID=15884&PageTypeID=4&KeyValue=02-2N-11-0084-0370-0020",
    "https://lakecopropappr.com/property-details.aspx?ParcelID=06-18-24-039600049130",
    "https://www.pa.marion.fl.us/PRC.aspx?key=569127&YR=2026&mName=False&mSitus=False",
    "https://www.pamartinfl.gov/app/search/view/68588",
    "https://ocpaweb.ocpafl.org/parcelsearch/Parcel%20ID/312427000000052",
    "https://pbcpao.gov/Property/Details?parcelId=74-43-43-18-03-000-0043",
    "https://search.pascopa.com/parcel.aspx?parcel=152636095E000020950",
    "https://www.polkflpa.gov/CamaDisplay.aspx?migratedFrom=org&OutputMode=Display&SearchType=RealEstate&Page=FindByID&ParcelID=252602000000031230&cookie_test=true",
    "https://apps.putnam-fl.com/pa/property/?type=api&parcel=03-10-24-9070-0140-0530",
    "https://srcpa.gov/parcel?id=40-1N-28-0090-44600-0010",
    "https://www.sc-pa.com/propertysearch/parcel/0434030097",
    "https://www.scpafl.org/search/parcels/details?PID=07-20-31-513-0000-0490",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=960&LayerID=21179&PageTypeID=4&PageID=9059&Q=1417436712&KeyValue=1702700000",
    "https://vcpa.vcgov.org/parcel/summary/?altkey=701632040040",
    "https://apps.putnam-fl.com/pa/property/?type=api&parcel=36-09-23-5740-0150-0100",
    "https://srcpa.gov/parcel?id=19-1N-28-0000-08901-0000",
    "https://www.sc-pa.com/propertysearch/parcel/0068100045",
    "https://www.scpafl.org/search/parcels/details?PID=03-21-30-506-0M00-0310",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=960&LayerID=21179&PageTypeID=4&PageID=9059&Q=1417436712&KeyValue=1702700000",
    "https://vcpa.vcgov.org/parcel/summary/?altkey=523613001880",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=835&LayerID=15172&PageTypeID=4&PageID=6829&KeyValue=30-1S-21-41100-028-0100",
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=896&LayerID=16944&PageTypeID=4&PageID=7615&Q=1897322886&KeyValue=00000000-00-0007-0018",
]

appraisal_links_abbreviated = [
    "https://qpublic.schneidercorp.com/Application.aspx?AppID=1081&LayerID=26490&PageTypeID=4&PageID=10770&Q=320373606&KeyValue=10617-016-000",
    "https://bakerpa.com/propertydetails.php?parcel=362S21005100330040",
    "https://qpublic.schneidercorp.com/application.aspx?AppID=834&LayerID=15170&PageTypeID=4&PageID=6825&Q=192963963&KeyValue=01755-000-000",
    "https://paopropertysearch.coj.net/Basic/Detail.aspx?RE=1677581005",
    "https://www.escpa.org/cama/Detail_a.aspx?s=191S311103006001",
]

# %%
appraisal_html_dict = {}

for link in appraisal_links_abbreviated:
    r = requests.get(link, timeout=60)
    time.sleep(5)
    r.raise_for_status()
    html_text = r.text
    appraisal_markdown_dict.update({link : html_text})
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       4 r = requests.get(link, timeout=60)
#       5 time.sleep(5)
# ----> 6 r.raise_for_status()
#       7 html_text = r.text
#       8 appraisal_markdown_dict.update({link : html_text})
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://qpublic.schneidercorp.com/Application.aspx?AppID=1081&LayerID=26490&PageTypeID=4&PageID=10770&Q=320373606&KeyValue=10617-016-000

# %%
print(appraisal_markdown_dict["https://qpublic.schneidercorp.com/application.aspx?AppID=834&LayerID=15170&PageTypeID=4&PageID=6825&Q=192963963&KeyValue=01755-000-000"])
# Out:
# Title: Just a moment...
#
# URL Source: https://qpublic.schneidercorp.com/application.aspx?AppID=834&LayerID=15170&PageTypeID=4&PageID=6825&Q=192963963&KeyValue=01755-000-000
#
# ...
#
# Markdown Content:
# ![Image 1: Icon for qpublic.schneidercorp.com](https://qpublic.schneidercorp.com/favicon.ico)
#
# qpublic.schneidercorp.com
# -------------------------
#
# Performing security verification
# --------------------------------
#
# This website uses a security service to protect against malicious bots. This page is displayed while the website verifies you are not a bot.
